# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys

# %%
sys.path.append("../")

# %%
from image_analysis.generate_image import *
from image_analysis.image_synthetic import *
from image_analysis.change_background import *

# %%
black = generate_black(20, 20)
white = generate_white(20, 20)
red = generate_red(20, 20)
green = generate_green(20, 20)
blue = generate_blue(20, 20)

# %%
fig, axs = plt.subplots(2, 2, figsize=(5, 5))
axs[0, 0].imshow(black)
axs[0, 1].imshow(white)
axs[1, 0].imshow(red)
axs[1, 1].imshow(green)

# pltだし逆
# 赤のとこに青がでる
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
del black, white, red, green, blue

# %%
black = generate_black(200, 200)
white = generate_white(30, 30)
synthetic_image = synthetic(black, white, [0, 0])
plt.imshow(synthetic_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
del black, white

# %%
black = generate_black(200, 200)
white_line_on_black = draw_vertical_line(black, [255, 255, 255], 100)
plt.imshow(white_line_on_black)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
double_line_on_black = draw_horizontal_line(white_line_on_black, [255, 255, 255], 100)
plt.imshow(double_line_on_black)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# error_handling test
image = np.zeros(shape=(10, 10, 3))
_ = draw_horizontal_line(image, [2, 2], 3)
# Out:
# color list length must be 3

# %%
del black, white_line_on_black, double_line_on_black, image

# %%
image = cv2.imread("../input_image/top_1.png")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
changed_image = black_to_white(image)
plt.imshow(cv2.cvtColor(changed_image, cv2.COLOR_BGR2RGB))

# %%
cv2.imwrite("../input_image/top_1_altered.png", changed_image)
# Out:
# True

# %%
eraser = cv2.imread("../input_image/top_3.png")
changed_eraser = black_to_white(eraser)
plt.imshow(cv2.cvtColor(changed_eraser, cv2.COLOR_BGR2RGB))

# %%
cv2.imwrite("../input_image/top_3_altered.png", changed_eraser)
# Out:
# True
